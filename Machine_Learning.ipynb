# %%
# importing the libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# For clustering and classification
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
# pip install keras-tuner
from keras_tuner.tuners import RandomSearch

# Import train_test_split, cross_val_score and GridSearchCV functions
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

# For TSA
# pip install pmdarima
from pmdarima import auto_arima
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# For sentiment analysis
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
#pip install wordcloud
from wordcloud import WordCloud 
from nltk.tokenize import RegexpTokenizer
from sklearn.naive_bayes import MultinomialNB

import warnings
warnings.filterwarnings('ignore')

# Increase columns and rows for display to have a better view of the dataframe
pd.set_option("display.max_columns", 100)
pd.set_option("display.min_rows", 100)
# %matplotlib inline

# %%
# Read dataset
daft_df = pd.read_csv('daft.csv')
daft_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6986 entries, 0 to 6985
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   price            6986 non-null   float64
#  1   floor_area       6986 non-null   float64
#  2   beds             6986 non-null   float64
#  3   baths            6986 non-null   float64
#  4   property_type    6986 non-null   object
#  5   floor_area_unit  6986 non-null   object
#  6   price_sq_mt      6986 non-null   float64
# dtypes: float64(5), object(2)
# memory usage: 382.2+ KB

# %% [markdown]
# ## Clustering

# %%
daft_df2 = daft_df[(daft_df['property_type'] == 'Apartment')|(daft_df['property_type'] == 'Detached')]
daft_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4880 entries, 0 to 6985
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   price            4880 non-null   float64
#  1   floor_area       4880 non-null   float64
#  2   beds             4880 non-null   float64
#  3   baths            4880 non-null   float64
#  4   property_type    4880 non-null   object
#  5   floor_area_unit  4880 non-null   object
#  6   price_sq_mt      4880 non-null   float64
# dtypes: float64(5), object(2)
# memory usage: 305.0+ KB

# %%
# Selecting price and floor area features for analysis on apartment vs detached houses
x = daft_df2.iloc[:, [0, 1]].values

# %%
# Finding the optimum number of clusters

# Declare an array for the sum of the squared distance between each member of the cluster and its centroid.
wcss = []

# Set the loop from the minimum and maximum values
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
# inertia_float: Sum of squared distances of samples to their closest cluster center.

# Plotting the results onto a line graph, allowing us to observe 'The elbow'
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')    # within cluster sum of squares
plt.show()

# %%
# Applying KMeans to the dataset/ Creating the kmeans classifier
kmeans = KMeans(n_clusters = 4, max_iter = 300, n_init = 10, random_state = 0)

# n_initint, default = 10, Number of time the k-means algorithm will be run with different centroid seeds. 
# The final results will be the best output of n_init consecutive runs in terms of inertia.
y_kmeans = kmeans.fit_predict(x)

print(y_kmeans)
# Out:
# [3 0 2 ... 0 2 0]

# %%
# Visualising the clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 50, c = 'red', label = 'Detached')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 50, c = 'blue', label = 'Detached')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 50, c = 'green', label = 'Apartment')
plt.scatter(x[y_kmeans == 3, 0], x[y_kmeans == 3, 1], s = 50, c = 'brown', label = 'Detached')
# For two clusters, remove the second last two python statements from the above four python statements

# Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1:2], s = 100, c = 'yellow', label = 'Centroids')
plt.xlabel('Price')
plt.ylabel('floor_area')

# A legend is an area describing the elements of the graph. In the matplotlib library, there's a function called legend() 
# which is used to Place a legend on the axes.
plt.legend()

# %% [markdown]
# ## Classification

# %% [markdown]
# ### RandomForestClassifier

# %%
X = daft_df.drop(['property_type','floor_area_unit'], axis=1)
y = daft_df['property_type']

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # 70% training and 30% test

# Create Classifier
RFclf1 = RandomForestClassifier(random_state=42) # default n_estimators = 100

# Train the model using the training sets
RFclf1.fit(X_train,y_train)

# Make predictions on the testing set
y_pred = RFclf1.predict(X_test)

# Model Accuracy
print("Training set score: {:.2f}".format(RFclf1.score(X_train, y_train)))
print("Test set score: {:.2f}".format(RFclf1.score(X_test, y_test)))

# Calculate confusion_matrix
cm = metrics.confusion_matrix(y_test, y_pred)

# Call a method heatmap() to plot confusion matrix
sns.heatmap(cm, annot = True, linewidths = 2).set(title='Classification heatmap',xlabel='Property Type', ylabel='Property Type');

# print the classification_report based on y_test and y_predict
print(metrics.classification_report(y_test, y_pred))

# Cross validation
cv_scores = np.around(cross_val_score(RFclf1, X, y, scoring='accuracy', cv = 20),2).tolist()
cv_mean = round(np.mean(cv_scores),2)
cv_std = round(np.std(cv_scores),2)

print(f'Cross validation accuracy mean: {cv_mean} +/- {cv_std}')
print(f'Cross validation accuracy results: {cv_scores}')
# Out:
# Training set score: 0.99
# Test set score: 0.74
#               precision    recall  f1-score   support
#
#    Apartment       0.82      0.79      0.81       404
#     Detached       0.77      0.79      0.78      1060
#       Semi-D       0.63      0.62      0.63       632
#
#     accuracy                           0.74      2096
#    macro avg       0.74      0.73      0.74      2096
# weighted avg       0.74      0.74      0.74      2096
#
# Cross validation accuracy mean: 0.74 +/- 0.03
# Cross validation accuracy results: [0.77, 0.73, 0.76, 0.76, 0.77, 0.79, 0.75, 0.72, 0.75, 0.79, 0.7, 0.74, 0.69, 0.72, 0.75, 0.74, 0.74, 0.73, 0.74, 0.7]

# %%
# # Commented lines below: it takes too long to run, results commented in the code and report

# X = daft_df.drop(['property_type','floor_area_unit'], axis=1)
# y = daft_df['property_type']

# # Split dataset into training set and test set
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # 70% training and 30% test

# # Initialise RandomForestClassifier
# rfclf = RandomForestClassifier()

# # parameter dictionary for GridSearchCV
# param_grid = {
#     'n_estimators': [100,500,700,900,1000],
#     'max_depth': [None,10,15,20,25,50]
# }

# # Modelling with GridSearchCV result
# rfclfgr = GridSearchCV(rfclf, param_grid, cv=10)
# rfclfgr.fit(X_train, y_train)

# print(rfclfgr.best_estimator_)

# # result --> RandomForestClassifier(max_depth=10, , n_estimators=700) 20 minutes to run

# # Make predictions on the testing set
# y_pred = rfclfgr.predict(X_test)

# # Model Accuracy
# print("Training set score: {:.2f}".format(rfclfgr.score(X_train, y_train))) # --> 0.87
# print("Test set score: {:.2f}".format(rfclfgr.score(X_test, y_test))) # --> 0.76

# # Calculate confusion_matrix
# cm = metrics.confusion_matrix(y_test, y_pred)

# # Call a method heatmap() to plot confusion matrix
# sns.heatmap(cm, annot = True, linewidths = 2).set(title='Classification heatmap',xlabel='Property Type', ylabel='Property Type');

# # print the classification_report based on y_test and y_predict
# print(metrics.classification_report(y_test, y_pred))

# # # Cross validation
# # cv_scores = np.around(cross_val_score(rfclfgr, X, y, scoring='accuracy', cv = 20),2).tolist()
# # cv_mean = round(np.mean(cv_scores),2)
# # cv_std = round(np.std(cv_scores),2)

# # print(f'Cross validation accuracy mean: {cv_mean} +/- {cv_std}')
# # print(f'Cross validation accuracy results: {cv_scores}')

# # Cross validation accuracy mean: 0.77 +/- 0.03
# # Cross validation accuracy results: [0.78, 0.76, 0.79, 0.78, 0.8, 0.81, 0.78, 0.75, 0.81, 0.81, 0.74, 0.78, 0.72, 0.74, 0.77, 0.75, 0.74, 0.76, 0.75, 0.7]

# %% [markdown]
# ### Artificial Neural Network

# %%
# In order to be able to train the model I need np array type target so first 
# encoding the target feature and then converting the resulting 3 columns into an array

daft_df3 = daft_df.copy()
daft_df3 = pd.get_dummies(data=daft_df3, columns=['property_type'])
daft_df3.head(2)
# Out:
#        price  floor_area  beds  baths floor_area_unit  price_sq_mt  \
# 0  2300000.0       600.0   6.0    5.0              m²       3833.0
# 1   499000.0       213.0   3.0    3.0              m²       2343.0
#
#    property_type_Apartment  property_type_Detached  property_type_Semi-D
# 0                        0                       1                     0
# 1                        0                       1                     0

# %%
X = daft_df3.drop(['floor_area_unit','property_type_Apartment','property_type_Detached','property_type_Semi-D'], axis=1)
y = daft_df3[['property_type_Apartment', 'property_type_Detached', 'property_type_Semi-D']]

# convert the features and target variables to numpy arrays
X = np.array(X)
y = np.array(y)

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # 70% training and 30% test

# Use standardized data
sc = StandardScaler()

# Train the model 
X_train = sc.fit_transform(X_train)

# Transforms the test data
X_test = sc.transform(X_test)

# %%
X_test[0], y_test[0]
# Out:
# (array([-0.28559627, -0.88483982, -1.15773977, -1.14960469,  1.51449887]),
#  array([1, 0, 0], dtype=uint8))

# %%
# Create an ANN model
model = Sequential()
model.add(Dense(64, input_dim=5, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(3, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=1000, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 1s 77ms/step - loss: 1.1463 - accuracy: 0.3771 - val_loss: 1.0976 - val_accuracy: 0.5014
# Epoch 2/50
# 5/5 [==============================] - 0s 29ms/step - loss: 1.0622 - accuracy: 0.5292 - val_loss: 1.0252 - val_accuracy: 0.5391
# Epoch 3/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9962 - accuracy: 0.5517 - val_loss: 0.9701 - val_accuracy: 0.5625
# Epoch 4/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.9452 - accuracy: 0.6127 - val_loss: 0.9263 - val_accuracy: 0.6460
# Epoch 5/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.9047 - accuracy: 0.6501 - val_loss: 0.8891 - val_accuracy: 0.6574
# Epoch 6/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8686 - accuracy: 0.6532 - val_loss: 0.8566 - val_accuracy: 0.6627
# Epoch 7/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8380 - accuracy: 0.6663 - val_loss: 0.8277 - val_accuracy: 0.6689
# Epoch 8/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8105 - accuracy: 0.6796 - val_loss: 0.8018 - val_accuracy: 0.6803
# Epoch 9/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7859 - accuracy: 0.6910 - val_loss: 0.7781 - val_accuracy: 0.6880
# Epoch 10/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7631 - accuracy: 0.6984 - val_loss: 0.7561 - val_accuracy: 0.6980
# Epoch 11/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7426 - accuracy: 0.7065 - val_loss: 0.7359 - val_accuracy: 0.7028
# Epoch 12/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7239 - accuracy: 0.7082 - val_loss: 0.7175 - val_accuracy: 0.7109
# Epoch 13/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7070 - accuracy: 0.7168 - val_loss: 0.7009 - val_accuracy: 0.7185
# Epoch 14/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.6917 - accuracy: 0.7284 - val_loss: 0.6860 - val_accuracy: 0.7295
# Epoch 15/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.6781 - accuracy: 0.7348 - val_loss: 0.6725 - val_accuracy: 0.7347
# Epoch 16/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.6655 - accuracy: 0.7425 - val_loss: 0.6608 - val_accuracy: 0.7395
# Epoch 17/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.6542 - accuracy: 0.7448 - val_loss: 0.6502 - val_accuracy: 0.7424
# Epoch 18/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.6443 - accuracy: 0.7499 - val_loss: 0.6406 - val_accuracy: 0.7467
# Epoch 19/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.6355 - accuracy: 0.7544 - val_loss: 0.6324 - val_accuracy: 0.7519
# Epoch 20/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.6278 - accuracy: 0.7581 - val_loss: 0.6246 - val_accuracy: 0.7576
# Epoch 21/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.6205 - accuracy: 0.7622 - val_loss: 0.6183 - val_accuracy: 0.7591
# Epoch 22/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.6147 - accuracy: 0.7638 - val_loss: 0.6128 - val_accuracy: 0.7600
# Epoch 23/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.6091 - accuracy: 0.7632 - val_loss: 0.6081 - val_accuracy: 0.7600
# Epoch 24/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.6047 - accuracy: 0.7634 - val_loss: 0.6041 - val_accuracy: 0.7615
# Epoch 25/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.6004 - accuracy: 0.7638 - val_loss: 0.6005 - val_accuracy: 0.7600
# Epoch 26/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5967 - accuracy: 0.7646 - val_loss: 0.5976 - val_accuracy: 0.7605
# Epoch 27/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5935 - accuracy: 0.7640 - val_loss: 0.5948 - val_accuracy: 0.7624
# Epoch 28/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5902 - accuracy: 0.7636 - val_loss: 0.5924 - val_accuracy: 0.7634
# Epoch 29/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5876 - accuracy: 0.7644 - val_loss: 0.5905 - val_accuracy: 0.7634
# Epoch 30/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5852 - accuracy: 0.7646 - val_loss: 0.5885 - val_accuracy: 0.7634
# Epoch 31/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5830 - accuracy: 0.7652 - val_loss: 0.5865 - val_accuracy: 0.7634
# Epoch 32/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5807 - accuracy: 0.7642 - val_loss: 0.5852 - val_accuracy: 0.7638
# Epoch 33/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5789 - accuracy: 0.7648 - val_loss: 0.5835 - val_accuracy: 0.7643
# Epoch 34/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5772 - accuracy: 0.7640 - val_loss: 0.5821 - val_accuracy: 0.7638
# Epoch 35/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5759 - accuracy: 0.7650 - val_loss: 0.5807 - val_accuracy: 0.7648
# Epoch 36/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5745 - accuracy: 0.7634 - val_loss: 0.5803 - val_accuracy: 0.7672
# Epoch 37/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5731 - accuracy: 0.7654 - val_loss: 0.5792 - val_accuracy: 0.7657
# Epoch 38/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5717 - accuracy: 0.7661 - val_loss: 0.5782 - val_accuracy: 0.7638
# Epoch 39/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5707 - accuracy: 0.7673 - val_loss: 0.5770 - val_accuracy: 0.7615
# Epoch 40/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5697 - accuracy: 0.7658 - val_loss: 0.5759 - val_accuracy: 0.7657
# Epoch 41/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5687 - accuracy: 0.7658 - val_loss: 0.5752 - val_accuracy: 0.7672
# Epoch 42/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5677 - accuracy: 0.7658 - val_loss: 0.5746 - val_accuracy: 0.7672
# Epoch 43/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5668 - accuracy: 0.7652 - val_loss: 0.5741 - val_accuracy: 0.7643
# Epoch 44/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5660 - accuracy: 0.7673 - val_loss: 0.5733 - val_accuracy: 0.7657
# Epoch 45/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5652 - accuracy: 0.7667 - val_loss: 0.5728 - val_accuracy: 0.7662
# Epoch 46/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5644 - accuracy: 0.7669 - val_loss: 0.5723 - val_accuracy: 0.7653
# Epoch 47/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5638 - accuracy: 0.7669 - val_loss: 0.5714 - val_accuracy: 0.7653
# Epoch 48/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5628 - accuracy: 0.7667 - val_loss: 0.5711 - val_accuracy: 0.7662
# Epoch 49/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5620 - accuracy: 0.7671 - val_loss: 0.5706 - val_accuracy: 0.7624
# Epoch 50/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5613 - accuracy: 0.7673 - val_loss: 0.5700 - val_accuracy: 0.7648

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print('Test accuracy: {:.2f}'.format(accuracy))
print('Test loss: {:.2f}'.format(loss))

# Get training and test loss and accuracy histories
training_loss = history.history["loss"]
test_loss = history.history["val_loss"]
training_accuracy = history.history["accuracy"]
test_accuracy = history.history["val_accuracy"]

# Create count of the number of epochs
epoch_count = range(1, len(training_loss) + 1)

# Visualize loss history
plt.plot(epoch_count, training_loss, "r--")
plt.plot(epoch_count, test_loss, "b-")
plt.plot(epoch_count, training_accuracy, "g--")
plt.plot(epoch_count, test_accuracy, "y-")
plt.legend(["Training Loss", "Test Loss", "Training Accuracy", "Test Accuracy"])
plt.xlabel("Epoch")
plt.ylabel("Loss / Accuracy")
plt.show();
# Out:
# 66/66 [==============================] - 0s 1ms/step - loss: 0.5700 - accuracy: 0.7648
# Test accuracy: 0.76
# Test loss: 0.57

# %% [markdown]
# ### Use Keras tuner to try different combinations of layers and neurons

# %%
def build_model(hp):
    model = Sequential()
    model.add(Dense(64, input_dim=5, activation='relu'))
    for i in range(hp.Int('layers',1,5)):
        model.add(Dense(
            units=hp.Int('units_'+ str(i),32,512,step=32),
            activation= 'relu'))
    model.add(Dense(3, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
import os

tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=2,
    overwrite=True,
    directory=os.path.normpath('/mydir'),
    project_name='keras_tuner'
)

# Note: in order to make this tuner work I had to create a directory C:\mydir (new folder called mydir in disk C main), 
# before it was failing to create the directory due to the use of backslashes as I found online.
# Keras documentation does not explain this in detail and it took a long research to solve this issue.
# but please read this note for replicability

# %%
tuner.search(X_train, y_train, epochs=50, batch_size=1000, validation_data=(X_test, y_test))
# Out:
# Trial 5 Complete [00h 00m 13s]
# val_accuracy: 0.7788645029067993
#
# Best val_accuracy So Far: 0.7788645029067993
# Total elapsed time: 00h 01m 11s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in \mydir\keras_tuner
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 4 summary
# Hyperparameters:
# layers: 1
# units_0: 512
# units_1: 96
# units_2: 256
# units_3: 32
# units_4: 256
# Score: 0.7788645029067993
#
# Trial 2 summary
# Hyperparameters:
# layers: 1
# units_0: 352
# units_1: 480
# units_2: 128
# units_3: 160
# units_4: 224
# Score: 0.7774331867694855
#
# Trial 0 summary
# Hyperparameters:
# layers: 5
# units_0: 416
# units_1: 32
# units_2: 32
# units_3: 32
# units_4: 32
# Score: 0.7764790058135986
#
# Trial 3 summary
# Hyperparameters:
# layers: 5
# units_0: 224
# units_1: 352
# units_2: 32
# units_3: 64
# units_4: 448
# Score: 0.7757633328437805
#
# Trial 1 summary
# Hyperparameters:
# layers: 1
# units_0: 128
# units_1: 160
# units_2: 512
# units_3: 224
# units_4: 288
# Score: 0.7729007601737976

# %%
# Get the best model.
models = tuner.get_best_models(num_models=1)
best_model = models[0]
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                384
#
#  dense_1 (Dense)             (None, 512)               33280
#
#  dense_2 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 35,203
# Trainable params: 35,203
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### tuner best_model
#
# Model: "sequential"
#
#  Layer (type)       /         Output Shape        /      Param
#
#  dense (Dense)      /         (None, 64)          /      384
#
#  dense_1 (Dense)    /         (None, 512)         /      33280
#
#  dense_2 (Dense)    /         (None, 3)           /      1539

# %%
# Create an ANN model
model = Sequential()
model.add(Dense(64, input_dim=5, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(3, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=1000, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 1s 53ms/step - loss: 1.0171 - accuracy: 0.4683 - val_loss: 0.9023 - val_accuracy: 0.6260
# Epoch 2/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.8609 - accuracy: 0.6421 - val_loss: 0.7825 - val_accuracy: 0.6827
# Epoch 3/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7709 - accuracy: 0.6906 - val_loss: 0.7039 - val_accuracy: 0.7271
# Epoch 4/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7134 - accuracy: 0.7247 - val_loss: 0.6526 - val_accuracy: 0.7514
# Epoch 5/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6748 - accuracy: 0.7344 - val_loss: 0.6218 - val_accuracy: 0.7595
# Epoch 6/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6510 - accuracy: 0.7479 - val_loss: 0.6033 - val_accuracy: 0.7739
# Epoch 7/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6346 - accuracy: 0.7581 - val_loss: 0.5920 - val_accuracy: 0.7805
# Epoch 8/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6249 - accuracy: 0.7609 - val_loss: 0.5836 - val_accuracy: 0.7820
# Epoch 9/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6153 - accuracy: 0.7628 - val_loss: 0.5764 - val_accuracy: 0.7758
# Epoch 10/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6077 - accuracy: 0.7622 - val_loss: 0.5691 - val_accuracy: 0.7758
# Epoch 11/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6006 - accuracy: 0.7607 - val_loss: 0.5632 - val_accuracy: 0.7786
# Epoch 12/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5930 - accuracy: 0.7597 - val_loss: 0.5589 - val_accuracy: 0.7796
# Epoch 13/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5878 - accuracy: 0.7632 - val_loss: 0.5548 - val_accuracy: 0.7772
# Epoch 14/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5827 - accuracy: 0.7652 - val_loss: 0.5520 - val_accuracy: 0.7781
# Epoch 15/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5785 - accuracy: 0.7677 - val_loss: 0.5483 - val_accuracy: 0.7781
# Epoch 16/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5751 - accuracy: 0.7661 - val_loss: 0.5462 - val_accuracy: 0.7796
# Epoch 17/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5725 - accuracy: 0.7661 - val_loss: 0.5447 - val_accuracy: 0.7791
# Epoch 18/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5703 - accuracy: 0.7673 - val_loss: 0.5432 - val_accuracy: 0.7767
# Epoch 19/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5678 - accuracy: 0.7671 - val_loss: 0.5417 - val_accuracy: 0.7786
# Epoch 20/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5656 - accuracy: 0.7671 - val_loss: 0.5415 - val_accuracy: 0.7786
# Epoch 21/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5643 - accuracy: 0.7677 - val_loss: 0.5398 - val_accuracy: 0.7791
# Epoch 22/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5626 - accuracy: 0.7685 - val_loss: 0.5388 - val_accuracy: 0.7791
# Epoch 23/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5604 - accuracy: 0.7695 - val_loss: 0.5396 - val_accuracy: 0.7772
# Epoch 24/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5594 - accuracy: 0.7699 - val_loss: 0.5375 - val_accuracy: 0.7791
# Epoch 25/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5583 - accuracy: 0.7706 - val_loss: 0.5365 - val_accuracy: 0.7786
# Epoch 26/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5568 - accuracy: 0.7712 - val_loss: 0.5363 - val_accuracy: 0.7781
# Epoch 27/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5555 - accuracy: 0.7720 - val_loss: 0.5357 - val_accuracy: 0.7824
# Epoch 28/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5542 - accuracy: 0.7708 - val_loss: 0.5353 - val_accuracy: 0.7786
# Epoch 29/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5530 - accuracy: 0.7718 - val_loss: 0.5336 - val_accuracy: 0.7805
# Epoch 30/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5524 - accuracy: 0.7722 - val_loss: 0.5352 - val_accuracy: 0.7777
# Epoch 31/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.5508 - accuracy: 0.7706 - val_loss: 0.5331 - val_accuracy: 0.7801
# Epoch 32/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5507 - accuracy: 0.7722 - val_loss: 0.5318 - val_accuracy: 0.7844
# Epoch 33/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.5489 - accuracy: 0.7726 - val_loss: 0.5344 - val_accuracy: 0.7791
# Epoch 34/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5477 - accuracy: 0.7710 - val_loss: 0.5322 - val_accuracy: 0.7781
# Epoch 35/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.5474 - accuracy: 0.7736 - val_loss: 0.5318 - val_accuracy: 0.7820
# Epoch 36/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5462 - accuracy: 0.7720 - val_loss: 0.5327 - val_accuracy: 0.7810
# Epoch 37/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5456 - accuracy: 0.7724 - val_loss: 0.5305 - val_accuracy: 0.7791
# Epoch 38/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5446 - accuracy: 0.7732 - val_loss: 0.5306 - val_accuracy: 0.7815
# Epoch 39/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5437 - accuracy: 0.7732 - val_loss: 0.5312 - val_accuracy: 0.7801
# Epoch 40/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5433 - accuracy: 0.7748 - val_loss: 0.5298 - val_accuracy: 0.7820
# Epoch 41/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5423 - accuracy: 0.7746 - val_loss: 0.5306 - val_accuracy: 0.7805
# Epoch 42/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.5419 - accuracy: 0.7763 - val_loss: 0.5297 - val_accuracy: 0.7777
# Epoch 43/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.5409 - accuracy: 0.7753 - val_loss: 0.5306 - val_accuracy: 0.7786
# Epoch 44/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5399 - accuracy: 0.7757 - val_loss: 0.5290 - val_accuracy: 0.7815
# Epoch 45/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5391 - accuracy: 0.7763 - val_loss: 0.5295 - val_accuracy: 0.7810
# Epoch 46/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5388 - accuracy: 0.7748 - val_loss: 0.5288 - val_accuracy: 0.7796
# Epoch 47/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5385 - accuracy: 0.7753 - val_loss: 0.5278 - val_accuracy: 0.7791
# Epoch 48/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5376 - accuracy: 0.7763 - val_loss: 0.5279 - val_accuracy: 0.7801
# Epoch 49/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5369 - accuracy: 0.7751 - val_loss: 0.5283 - val_accuracy: 0.7834
# Epoch 50/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5358 - accuracy: 0.7767 - val_loss: 0.5297 - val_accuracy: 0.7772

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print('Test accuracy: {:.2f}'.format(accuracy))
print('Test loss: {:.2f}'.format(loss))

# Get training and test loss and accuracy histories
training_loss = history.history["loss"]
test_loss = history.history["val_loss"]
training_accuracy = history.history["accuracy"]
test_accuracy = history.history["val_accuracy"]

# Create count of the number of epochs
epoch_count = range(1, len(training_loss) + 1)

# Visualize loss history
plt.plot(epoch_count, training_loss, "r--")
plt.plot(epoch_count, test_loss, "b-")
plt.plot(epoch_count, training_accuracy, "g--")
plt.plot(epoch_count, test_accuracy, "y-")
plt.legend(["Training Loss", "Test Loss", "Training Accuracy", "Test Accuracy"])
plt.xlabel("Epoch")
plt.ylabel("Loss / Accuracy")
plt.show();
# Out:
# 66/66 [==============================] - 0s 2ms/step - loss: 0.5297 - accuracy: 0.7772
# Test accuracy: 0.78
# Test loss: 0.53

# %% [markdown]
# ## Time Series Analysis

# %%
# Read dataset 
rpi_df = pd.read_csv('res_price_index.csv')
rpi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2376 entries, 0 to 2375
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   month                    2376 non-null   object
#  1   country                  2376 non-null   object
#  2   residential_price_index  2376 non-null   float64
#  3   perc_change_prev         2376 non-null   float64
#  4   perc_change_yoy          2376 non-null   float64
# dtypes: float64(3), object(2)
# memory usage: 92.9+ KB

# %%
rpi_df2 = rpi_df[rpi_df['country']=='IE']
rpi_df2 = rpi_df2[['month','residential_price_index']]
rpi_df2['month'] = pd.to_datetime(rpi_df2['month'], format='%Y-%m-%d')
rpi_df2.set_index('month', inplace=True)
rpi_df2.head(4)
# Out:
#             residential_price_index
# month
# 2001-01-01                     73.3
# 2001-02-01                     73.9
# 2001-03-01                     74.5
# 2001-04-01                     75.2

# %%
rpi_df2.plot(figsize=(8,4),legend=True);

# %% [markdown]
# ### TSA with LinearRegression and RandomForestRegressor

# %%
# Creating input variable, price index of the previous month
rpi_df3 = rpi_df2.copy()
rpi_df3['rpi_prev1'] = rpi_df3['residential_price_index'].shift(+1)
rpi_df3.dropna(inplace=True)
rpi_df3
# Out:
#             residential_price_index  rpi_prev1
# month
# 2001-02-01                     73.9       73.3
# 2001-03-01                     74.5       73.9
# 2001-04-01                     75.2       74.5
# 2001-05-01                     75.2       75.2
# 2001-06-01                     75.5       75.2
# 2001-07-01                     76.1       75.5
# 2001-08-01                     76.9       76.1
# 2001-09-01                     77.1       76.9
# 2001-10-01                     77.4       77.1
# 2001-11-01                     77.2       77.4
# 2001-12-01                     76.8       77.2
# 2002-01-01                     75.7       76.8
# 2002-02-01                     76.3       75.7
# 2002-03-01                     76.6       76.3
# 2002-04-01                     78.4       76.6
# 2002-05-01                     77.9       78.4
# 2002-06-01                     78.2       77.9
# 2002-07-01                     78.0       78.2
# 2002-08-01                     79.4       78.0
# 2002-09-01                     80.4       79.4
# 2002-10-01                     81.8       80.4
# 2002-11-01                     81.7       81.8
# 2002-12-01                     82.2       81.7
# 2003-01-01                     81.8       82.2
# 2003-02-01                     82.6       81.8
# 2003-03-01                     83.8       82.6
# 2003-04-01                     85.5       83.8
# 2003-05-01                     86.1       85.5
# 2003-06-01                     85.0       86.1
# 2003-07-01                     86.2       85.0
# ...                             ...        ...
# 2020-07-01                    109.6      109.5
# 2020-08-01                    109.4      109.6
# 2020-09-01                    109.5      109.4
# 2020-10-01                    109.4      109.5
# 2020-11-01                    109.3      109.4
# 2020-12-01                    109.3      109.3
# 2021-01-01                    109.6      109.3
# 2021-02-01                    109.7      109.6
# 2021-03-01                    110.6      109.7
# 2021-04-01                    113.1      110.6
# 2021-05-01                    113.6      113.1
# 2021-06-01                    115.3      113.6
# 2021-07-01                    116.6      115.3
# 2021-08-01                    117.9      116.6
# 2021-09-01                    118.2      117.9
# 2021-10-01                    119.3      118.2
# 2021-11-01                    119.6      119.3
# 2021-12-01                    119.7      119.6
# 2022-01-01                    120.4      119.7
# 2022-02-01                    122.5      120.4
# 2022-03-01                    123.2      122.5
# 2022-04-01                    125.2      123.2
# 2022-05-01                    126.3      125.2
# 2022-06-01                    127.9      126.3
# 2022-07-01                    130.7      127.9
# 2022-08-01                    130.6      130.7
# 2022-09-01                    130.1      130.6
# 2022-10-01                    131.1      130.1
# 2022-11-01                    131.6      131.1
# 2022-12-01                    131.6      131.6
#
# [263 rows x 2 columns]

# %%
X = rpi_df3['rpi_prev1']
y = rpi_df3['residential_price_index']

X,y = np.array(X), np.array(y)
X,y = X.reshape(-1,1), y.reshape(-1,1)

X_train, X_test, y_train, y_test = X[:-40], X[-40:], y[:-40], y[-40:]
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((223, 1), (40, 1), (223, 1), (40, 1))

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
lr_pred = lr.predict(X_test)

rfr = RandomForestRegressor()
rfr.fit(X_train, y_train)
rfr_pred = rfr.predict(X_test)

# %%
# test set mean
mean = y_test.mean()
print(f'Test set mean: {mean}')

# RandomForest Root Mean Square Error
rmse_rf = sqrt(metrics.mean_squared_error(rfr_pred,y_test))
print(f'RandomForest Root Mean Square Error: {rmse_rf}')

# LinearRegression Root Mean Square Error
rmse_lr = sqrt(metrics.mean_squared_error(lr_pred,y_test))
print(f'LinearRegression Root Mean Square Error: {rmse_lr}')
# Out:
# Test set mean: 116.57249999999999
# RandomForest Root Mean Square Error: 4.31919748510704
# LinearRegression Root Mean Square Error: 1.09151125605809

# %%
plt.rcParams['figure.figsize'] = (6,4)
plt.plot(y_test, 'b-', label='Actual value')
plt.plot(rfr_pred, 'g--', label='RandomForest Predictions')
plt.plot(lr_pred, 'r--', label='LinearRegression Predictions')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### Predictions into the future using ARIMA model

# %%
# Apply auto_arima function to get best combination of orders for the model and dataset provided
auto_arima(rpi_df2['residential_price_index'], trace=True, suppress_warnings=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=580.597, Time=0.34 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=647.231, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=597.182, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=613.003, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=663.696, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=578.649, Time=0.21 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=600.580, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=579.738, Time=0.20 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=580.493, Time=0.42 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=601.213, Time=0.12 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=578.634, Time=0.23 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=591.689, Time=0.10 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=580.539, Time=0.40 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=591.669, Time=0.13 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=580.033, Time=0.60 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=578.309, Time=0.11 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=579.561, Time=0.10 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=594.820, Time=0.06 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=580.219, Time=0.19 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=580.273, Time=0.13 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=602.400, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=578.330, Time=0.11 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=593.996, Time=0.06 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=579.687, Time=0.26 sec
#
# Best model:  ARIMA(2,1,1)(0,0,0)[0]
# Total fit time: 4.104 seconds
# ARIMA(order=(2, 1, 1), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
# Split the model into training and testing but without taking to much from the tail 
# due to raising trend at the end, it would not be captured in the prediction
train=rpi_df2.iloc[:-12]
test=rpi_df2.iloc[-12:]
print(train.shape,test.shape)
# Out:
# (252, 1) (12, 1)

# %%
# Train the model with orders provided by auto_arima function
model=ARIMA(train['residential_price_index'],order=(2,1,1))
model=model.fit()
#model.summary()

# %%
# Prediction start and end index
start=len(train) #star to make prediction from the end of training set
end=len(train)+len(test)-1

# Make prediction
pred=model.predict(start=start,end=end,typ='levels')

# %%
mean = test['residential_price_index'].mean()
rmse = sqrt(mean_squared_error(pred,test['residential_price_index']))

print('mean = ', mean)
print('mean sqr err = ', rmse)
# Out:
# mean =  127.59999999999998
# mean sqr err =  5.824925973224695

# %%
# Train the model with orders provided by auto_arima function and entire dataset
model2 = ARIMA(rpi_df2['residential_price_index'],order=(2,1,1))
model2 = model2.fit()

# Make predictions into the future, 24 months from final record
pred = model2.predict(start=len(rpi_df2), end=len(rpi_df2)+24, typ='levels').rename('ARIMA Predictions')
print(pred)
# Out:
# 2023-01-01    132.044310
# 2023-02-01    132.535866
# 2023-03-01    133.017939
# 2023-04-01    133.482955
# 2023-05-01    133.930419
# 2023-06-01    134.360835
# 2023-07-01    134.774829
# 2023-08-01    135.173024
# 2023-09-01    135.556023
# 2023-10-01    135.924406
# 2023-11-01    136.278730
# 2023-12-01    136.619533
# 2024-01-01    136.947330
# 2024-02-01    137.262617
# 2024-03-01    137.565872
# 2024-04-01    137.857554
# 2024-05-01    138.138104
# 2024-06-01    138.407948
# 2024-07-01    138.667494
# 2024-08-01    138.917136
# 2024-09-01    139.157250
# 2024-10-01    139.388201
# 2024-11-01    139.610338
# 2024-12-01    139.823998
# 2025-01-01    140.029504
# Freq: MS, Name: ARIMA Predictions, dtype: float64

# %%
# Plot extended dataset with prediction
rpi_df2['residential_price_index'].plot(figsize=(8,4),legend=True)
pred.plot(legend=True)
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# ## Sentiment Analysis

# %% [markdown]
# ### News Topics

# %%
tj_df = pd.read_csv('theJournal.csv')
wc_df = pd.read_csv('worldconstructiontoday.csv')

data_raw_ireland = tj_df['0']
data_raw_world = wc_df['0']

# fix stop_words
stop_words_fixed = set(stopwords.words("english"))
stop_words_fixed.update(['.',',',':',"'",'’','%',"'s",'?','A','‘','”','“','say','said']) # add to set of stopwords

# Create and declare a function is_letter_only()
def is_letter_only(word):
    for char in word:
        if not char.isalpha():
            return False
    return True

# %%
# Define topics function to avoid duplicated code
# args: 
#     data = news titles
#     t = num of topics
#     w = words per topic

def topics(data, t, w):
    lemmatizer = WordNetLemmatizer()

# Declare and create an empty array
    data_cleaned_lm = []

# Create a loop for all documents
    for title in data:
        title = str(title).lower()
        title_cleaned = ' '.join(lemmatizer.lemmatize(word) for word in title.split() if is_letter_only(word)) # function is_letter_only described above
        data_cleaned_lm.append(title_cleaned)

# Declare and create an array (count_vector) by calling a method CountVectorizer()
    count_vector = CountVectorizer(stop_words = stop_words_fixed, max_features = None, max_df = 0.2, min_df = 2)

    data_cleaned = count_vector.fit_transform(data_cleaned_lm)    

# Declare and initialise an object 'lda' by calling a method LatentDirichletAllocation()
    lda = LatentDirichletAllocation(n_components = t, learning_method = 'batch', random_state = 42)

# Train the model
    lda.fit(data_cleaned)

# # Print all lda components
# print(lda.components_)

# Get all feature names
    terms = count_vector.get_feature_names_out()

# Print topics
    for topic_idx, topic in enumerate(lda.components_):
        print("Topic {}:" .format(topic_idx + 1))
        print(" ".join([terms[i] for i in topic.argsort()[-w:]]))

# %%
print('Irish "The Journal" three main topics on housing:')
topics(data_raw_ireland,3,6)

print('')

print('"World Construction Today" worldwide three main topics on housing:')
topics(data_raw_world,3,6)
# Out:
# Irish "The Journal" three main topics on housing:
# Topic 1:
# ha home minister new homeless people
# Topic 2:
# one taoiseach eviction crisis rent government
# Topic 3:
# year new price property house dublin
#
# "World Construction Today" worldwide three main topics on housing:
# Topic 1:
# site ha equipment new world industry
# Topic 2:
# million awarded project new contract ha
# Topic 3:
# launch leading announced building ha technology

# %% [markdown]
# Topics from irish journal:
# - new homes to homeless
# - rent crisis/ eviction
# - price new property in dublin
#
# Topics from worldconstruction:
# - new equipment for industry
# - project contracts
# - new building technology

# %% [markdown]
# ### Irish news titles sentiment analysis

# %%
it_df = pd.read_csv('irish_times.csv')
it_df.head()
# Out:
#                                                title  \
# 0  Builders discuss the housing crisis: ‘If this ...
# 1  Michael McDowell: Local authority housing powe...
# 2  Ratings agency warns on economic price of Iris...
# 3  Anne Enright on Dublin, A Writer’s City: every...
# 4  Cliff Taylor: Will the new housing plan work a...
#
#                                          description
# 0  Is the Government’s newest housing initiative,...
# 1  At the very heart of the present Government’s ...
# 2  DBRS Morningstar, which was alone among the wo...
# 3  It used to be said that some people give direc...
# 4  What has the Government done to try to get mor...

# %%
# Create an instance of SentimentIntensityAnalyzer
sent_analyzer = SentimentIntensityAnalyzer()

def format_output(output_dict):
  
    polarity = "neutral"

    if(output_dict['compound'] >= 0.05):
        polarity = "positive"

    elif(output_dict['compound'] <= -0.05):
        polarity = "negative"

    return polarity

def predict_sentiment(text):
  
    output_dict =  sent_analyzer.polarity_scores(text)
    return format_output(output_dict)

# %%
sent_data = pd.DataFrame(it_df['title'])
sent_data['vader_prediction'] = sent_data['title'].apply(predict_sentiment)
sent_data.sample(10)
# Out:
#                                                  title vader_prediction
# 362  House asking prices jump 9% in ‘aggressive’ ma...          neutral
# 733  It’s the 1970s all over again as house plants ...          neutral
# 351  Affordable housing model could earn State mone...          neutral
# 372  State needs to build ‘over 200,000 homes’ over...         negative
# 39         Eviction ban and a deepening housing crisis         negative
# 859               Soft landing for the housing market?          neutral
# 487  House price inflation surges to pandemic high ...          neutral
# 94   Government needs to ‘do much more on housing’,...          neutral
# 361  Cliff Taylor: No wonder the Government has the...         negative
# 19                   The business of providing housing          neutral

# %%
# Display count labelled titles
sent_data['vader_prediction'].value_counts()
# Out:
# neutral     411
# negative    297
# positive    192
# Name: vader_prediction, dtype: int64

# %%
# Display an example of ten news titles and sentiment prediction to see if it makes sense.
data_sample = sent_data.sample(10)
for i,j in zip(data_sample['title'], data_sample['vader_prediction']):
    print(f'News Title: {i}')
    print(f'VADER Sentiment Analysis: {j}')
    print('')
# Out:
# News Title: Doll’s house sells for ‘mad’ price of €48,000 at Kilkenny auction
# VADER Sentiment Analysis: neutral
#
# News Title: We have gone sale agreed on a house, but should we go through with it?
# VADER Sentiment Analysis: positive
#
# News Title: Barratt home sales slow in sign of storm clouds for UK housing
# VADER Sentiment Analysis: neutral
#
# News Title: Almost two-thirds of people believe house prices will rise in next 12 months
# VADER Sentiment Analysis: neutral
#
# News Title: Ending the eviction ban as housing crisis deepens
# VADER Sentiment Analysis: negative
#
# News Title: The housing crisis and the left
# VADER Sentiment Analysis: negative
#
# News Title: David McWilliams: Ireland builds houses at the wrong time, in the wrong place, at the wrong price
# VADER Sentiment Analysis: negative
#
# News Title: Deep problems in planning system complicating delivery of new housing
# VADER Sentiment Analysis: negative
#
# News Title: New housing data highlights the task facing the government
# VADER Sentiment Analysis: neutral
#
# News Title: House prices continue to cool as interest rates tick up
# VADER Sentiment Analysis: positive

# %%
data_pos = sent_data.loc[sent_data['vader_prediction']== 'positive']['title'].tolist()
data_neg = sent_data.loc[sent_data['vader_prediction']== 'negative']['title'].tolist()

# Load and fix stop words
stop_words = set(stopwords.words("english"))
stop_words.update(['.',',',':',';',"'",'’','%',"'s",'?','A','‘','”','“','The','-']) # add to set of stopwords

def word_freq(data):
    tokenized = []
    
    for i in data:
        tokenized_word = word_tokenize(i)
        tokenized.extend(tokenized_word)
    
    filtered = []

    # Loop to filter words
    for w in tokenized:
        if w not in stop_words:
            w= w.lower()
            filtered.append(w)
    
    lem = WordNetLemmatizer()
    lemmatized = []

    # Store all the words into an array 'stemmed_words'
    for w in filtered:
        lemmatized.append(lem.lemmatize(w))
    
    # Frequency of word
    fdist = FreqDist(lemmatized)

    # Display the frequency distribution
    print(fdist)

    # Display the most common words
    print(fdist.most_common(5))

    fdist.plot(10, cumulative = False)
    plt.show()

print(f"Word distribution of positives news titles from The Irish Times ({len(data_pos)} articles)")
word_freq(data_pos)
print("")
print(f"Word distribution of negatives news titles from The Irish Times ({len(data_neg)} articles)")
word_freq(data_neg)
# Out:
# Word distribution of positives news titles from The Irish Times (192 articles)
# <FreqDist with 808 samples and 1599 outcomes>
# [('house', 114), ('housing', 76), ('price', 64), ('growth', 23), ('dublin', 16)]
# Word distribution of negatives news titles from The Irish Times (297 articles)
# <FreqDist with 958 samples and 2301 outcomes>
# [('housing', 225), ('crisis', 125), ('house', 77), ('price', 59), ('ireland', 26)]

# %%
def wordcloud(x, color):
    wc = WordCloud(background_color=color, relative_scaling=0.5, max_words = 100, width = 800 , height = 400, collocations=False).generate(" ".join(x))
    plt.imshow(wc)
    plt.axis('off')
    plt.show()

print("Positive words")
wordcloud(data_pos,'white')
print("Negative words")
wordcloud(data_neg,'black')
# Out:
# Positive words
# Negative words

# %% [markdown]
# ### Validate VADER sentiment prediction
# Train other model with public labelled data and compare results with vader prediction on irish times titles

# %%
# Read public labelled data
labelled1 = pd.read_csv('amazon.txt', sep="\t", header=None)
labelled2 = pd.read_csv('imdb.txt', sep="\t", header=None)
labelled3 = pd.read_csv('yelp.txt', sep="\t", header=None)

# Create dataframe to train model
labelled = pd.concat([labelled1, labelled2, labelled3], ignore_index=True, sort=False)
labelled.columns = ["text", "polarity"]
labelled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2748 entries, 0 to 2747
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      2748 non-null   object
#  1   polarity  2748 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 43.1+ KB

# %%
# Pre-Prcoessing and Bag of Word Vectorization using Count Vectorizer
token = RegexpTokenizer(r'[a-zA-Z0-9]+')
cv    = CountVectorizer(stop_words=stop_words, ngram_range=(1, 1), tokenizer=token.tokenize)
text_counts = cv.fit_transform(labelled['text'])

#Splitting the data into trainig and testing
X_train, X_test, Y_train, Y_test = train_test_split(text_counts, labelled['polarity'], test_size=0.25, random_state=0)

# Training the model
MNB = MultinomialNB()
MNB.fit(X_train, Y_train)

# Caluclating the accuracy score of the model
predicted = MNB.predict(X_test)
accuracy_score = metrics.accuracy_score(predicted, Y_test)
print("Accuracy Score: ",accuracy_score)
# Out:
# Accuracy Score:  0.7889374090247453

# %% [markdown]
# MultinomialNB trained with 0.79 accuracy <br>
# Now predict on Irish times

# %%
# Remove 'neutral' to match test dataset 'polarity' column
unlabelled = sent_data.drop(sent_data[sent_data.vader_prediction == 'neutral'].index).reset_index(drop=True)

# Match column names
unlabelled.rename(columns={'title': 'text','vader_prediction':'polarity'}, inplace=True)

# Replace values to match test dataset 'polarity' column
repl_dict = {'negative':0, 'positive':1}
unlabelled.replace({'polarity':repl_dict}, inplace=True)

new_df = pd.concat([labelled, unlabelled], ignore_index=False, sort=False).reset_index(drop=True)

# index 0-2747 labelled to train model same as before
# predict polarity all dataset
# index 2748-3236 to compare with VADER

# %%
# Pre-Prcoessing and Bag of Word Vectorization using Count Vectorizer
token = RegexpTokenizer(r'[a-zA-Z0-9]+')
cv    = CountVectorizer(stop_words = stop_words,ngram_range = (1, 1),tokenizer = token.tokenize)
text_counts = cv.fit_transform(new_df['text'])

matrix = text_counts.toarray()

X_train = matrix[:2748]
Y_train = new_df.loc[:2747, 'polarity'].values
X_test = matrix

# Training the model
MNB = MultinomialNB()
MNB.fit(X_train, Y_train)

y_pred = MNB.predict(X_test)

new_df2 = new_df.copy()
new_df2['predicted_label'] = y_pred

# labelled
labelled_train = Y_train
labelled_test = new_df2.loc[:2747, 'predicted_label'].values

# Unlabelled
unlabelled_vader = new_df2.loc[2748:, 'polarity'].values
unlabelled_test = new_df2.loc[2748:, 'predicted_label'].values

labelled_accuracy_score = metrics.accuracy_score(labelled_test, labelled_train)
print("Accuracy Score on labelled (train set): ",labelled_accuracy_score)

# Show the classification report between actual label and MultinomialNB prediction
print(metrics.classification_report(labelled_test, labelled_train))

unlabelled_accuracy_score = metrics.accuracy_score(unlabelled_test, unlabelled_vader)
print("Accuracy Score on vader prediction: ",unlabelled_accuracy_score)

# Show the classification report between vader prediction and MultinomialNB
print(metrics.classification_report(unlabelled_test, unlabelled_vader))
# Out:
# Accuracy Score on labelled (train set):  0.9446870451237264
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94      1340
#            1       0.95      0.94      0.95      1408
#
#     accuracy                           0.94      2748
#    macro avg       0.94      0.94      0.94      2748
# weighted avg       0.94      0.94      0.94      2748
#
# Accuracy Score on vader prediction:  0.5460122699386503
#               precision    recall  f1-score   support
#
#            0       0.43      0.70      0.54       183
#            1       0.72      0.45      0.55       306
#
#     accuracy                           0.55       489
#    macro avg       0.58      0.58      0.55       489
# weighted avg       0.61      0.55      0.55       489
